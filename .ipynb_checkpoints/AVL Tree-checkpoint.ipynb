# %% [raw]
# class Node(object):
#
#     def __init__(self, data):
#         self.leftChild = None;
#         self.rightChild = None;
#         self.data = data;
#         self.height = 0;
#
# class AVL(object):
#
#     def __init__(self):
#         self.root = None;
#
#
#     def getHeight(self, node):
#         if not node:
#             return -1;
#
#         return node.height;
#     def calcBalance(self, node):
#         if not node:
#             return 0;
#
#         return self.getHeight(node.leftChild) - self.getHeight(node.rightChild);
#
#     def rotateRight(self, node):
#         print("Rotating right");
#         tempNode = node.leftChild;
#
#         node.leftChild = tempNode.rigthChild;
#         tempNode.rightChild = node;
#         node.height = max(self.getHeight(node.leftChild), self.getHeight(node.rightChild)) + 1;
#         tempNode = max(self.getHeight(tempNode.leftChild), self.getHeight(tempNode.rightChild)) + 1;
#         return tempNode;
#
#      def rotateLeft(self, node):
#         print("Rotatingleft");
#         tempNode = node.rightChild;
#
#         node.rightChild = tempNode.leftChild;
#
#         tempNode.leftChild = node;
#
#         node.height = max(self.getHeight(node.leftChild), self.getHeight(node.rightChild)) + 1;
#         tempNode = max(self.getHeight(tempNode.leftChild), self.getHeight(tempNode.rightChild)) + 1;
#         return tempNode;
#
#
#     def insert(self, data):
#         self.root = self.insertNode(data, self.root)
#
#     def insertNode(self, data, node):
#         if not node:
#             return Node(data);
#
#         if data > node.data:
#             node.rightChild = self.insertNode(data, node.rightChild);
#
#         else:
#             node.leftChild = self.insertNode(data, node.leftChild);
#         return self.settelViolation(data, node);
#
#     def settleViolation(self, data, node):
#
#         balance = calcBalance(node);
#
#         if balance > 1 and data < node.leftChild:
#
#             return self.rotateLeft(node);
#         if balance < 1 and data > node.rightChild:
#
#             return self.rotateRight(node);
#
#         if if balance < 1 and data > node.leftChild:
#             node.leftChild = self.rotateLeft();
#             return self.rotateRight(node

# %%
class Node(object):
    
    def __init__(self, data):
        self.leftChild = None;
        self.rightChild = None;
        self.data = data;
        self.height = 0;
        
class AVL(object):
    
    def __init__(self):
        self.root = None;
        
        
    def getHeight(self, node):
        if not node:
            return -1;
        
        return node.height;
    def calcBalance(self, node):
        if not node:
            return 0;
        
        return self.getHeight(node.leftChild) - self.getHeight(node.rightChild);
    
    def rotateRight(self, node):
        print("Rotating right");
        tempNode = node.leftChild;
        
        node.leftChild = tempNode.rigthChild;
        tempNode.rightChild = node;
        node.height = max(self.getHeight(node.leftChild), self.getHeight(node.rightChild)) + 1;
        tempNode = max(self.getHeight(tempNode.leftChild), self.getHeight(tempNode.rightChild)) + 1;
        return tempNode;
    
    def rotateLeft(self, node):
        print("Rotatingleft");
        tempNode = node.rightChild;
        
        node.rightChild = tempNode.leftChild;
        
        tempNode.leftChild = node;
        
        node.height = max(self.getHeight(node.leftChild), self.getHeight(node.rightChild)) + 1;
        tempNode = max(self.getHeight(tempNode.leftChild), self.getHeight(tempNode.rightChild)) + 1;
        return tempNode;
    
    
    def insert(self, data):
        self.root = self.insertNode(data, self.root)
    
    def insertNode(self, data, node):
        if not node:
            return Node(data);
        
        if data > node.data:
            node.rightChild = self.insertNode(data, node.rightChild);
            
        else:
            node.leftChild = self.insertNode(data, node.leftChild);
        return self.settleViolation(data, node);
    
    def settleViolation(self, data, node):
        
        balance = self.calcBalance(node);
        
        if balance > 1 and data < node.leftChild.data:
            print("ll rotation")
            return self.rotateLeft(node);
        if balance < 1 and data > node.rightChild.data:
            print("rr rotation")
            return self.rotateRight(node);
        
        if balance < 1 and data > node.leftChild.data:
            print("lr rotation")
            node.leftChild = self.rotateLeft(node.leftChild);
            return self.rotateRight(node)
            
        if balance > 1 and data < node.rightChild.data:
            print("rl rotation")
            node.rightChild = self.rotateRight(node.rightChild);
            return self.rotateLeft(node);
        
    def traverse(self):
        if self.root:
            self.InOrd(self.root);
    def InOrd(self, node):
        if node.leftChild:
            self.InOrd(node.leftChild);
        print("%d" % node.data);
        
        if node.rightChild:
            self.InOrd(node.rightChild);

# %%
tree = AVL();

# %%
tree.insert(1)

# %%
tree.insert(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-100ea4f63e26> in <module>
# ----> 1 tree.insert(2)
#
# <ipython-input-29-7df8e5dc2060> in insert(self, data)
#      48
#      49     def insert(self, data):
# ---> 50         self.root = self.insertNode(data, self.root)
#      51
#      52     def insertNode(self, data, node):
#
# <ipython-input-29-7df8e5dc2060> in insertNode(self, data, node)
#      59         else:
#      60             node.leftChild = self.insertNode(data, node.leftChild);
# ---> 61         return self.settleViolation(data, node);
#      62
#      63     def settleViolation(self, data, node):
#
# <ipython-input-29-7df8e5dc2060> in settleViolation(self, data, node)
#      72             return self.rotateRight(node);
#      73
# ---> 74         if balance < 1 and data > node.leftChild.data:
#      75             print("lr rotation")
# ...
